
       [np.nan, np.nan, np.nan, np.nan, np.nan],
       [np.nan, np.nan, np.nan, np.nan, np.nan],
       [np.nan, np.nan, np.nan, np.nan, np.nan],
       [np.nan, np.nan, np.nan, np.nan, np.nan]]

b_tP = [[0.0002,    0.0002,    0.0002,    0.0002,    0.0002,], 
       [0.0002,    0.0002,    0.0002,    0.0002,    0.0002,],
       [0.0003,    0.0003,    0.0003,    0.0005,    0.0004,],
       [0.0006,    0.0006,    0.0005,    0.0005,    0.0005,],
       [0.0006,    0.0008,    0.0007,    0.0006,    0.0006,],
       [0.0008,    0.0008,    0.0008,    0.0008,    0.0008,],
       [0.0011,    0.0011,    0.0011,    0.0013,    0.0013,],
       [0.0018,    0.0017,    0.0019,    0.0018,    0.0018,],
       [0.0028,    0.0028,    0.0028,    0.0028,    0.0035,],
       [0.0060,    0.0045,    0.0044,    0.0045,    0.0045,],
       [0.0082,    0.0081,    0.0089,    0.0082,    0.0081,],
       [0.0191,    0.0176,    0.0176,    0.0175,    0.0175,],
       [0.0377,    0.0374,    0.0376,    0.0374,    0.0375,],
       [0.0763,    0.0756,    0.0755,    0.0754,    0.0756,],
       [0.1529,    0.1530,    0.1535,    0.1615,    0.1529,],
       [0.3144,    0.3121,    0.3205,    0.3098,    0.3093,],
       [0.6282,    0.6269,    0.6270,    0.6282,    0.6272,],
       [1.3103,    1.3101,    1.3064,    1.3098,    1.3100,],
       [2.7028,    2.6817,    2.7016,    2.6884,    2.6894,],
       [5.4930,    5.4840,    5.4781,    5.4897,    5.4842,],]

# %%
m_tS = [[0.0011,    0.0006,    0.0006,    0.0006,    0.0006,], 
       [0.0014,    0.0015,    0.0015,    0.0015,    0.0015,],
       [0.0034,    0.0033,    0.0033,    0.0038,    0.0038,],
       [0.0079,    0.0073,    0.0073,    0.0079,    0.0083,],
       [0.0162,    0.0179,    0.0162,    0.0180,    0.0162,],
       [0.0379,    0.0361,    0.0359,    0.0358,    0.0360,],
       [0.0790,    0.0802,    0.0792,    0.0792,    0.0792,],
       [0.1739,    0.1735,    0.1738,    0.1742,    0.1737,],
       [0.3798,    0.3795,    0.3803,    0.3794,    0.3800,],
       [0.8267,    0.8286,    0.8263,    0.8273,    0.8261,],
       [1.7952,    1.7951,    1.7924,    1.7951,    1.7907,],
       [3.8732,    3.8729,    3.8821,    3.8709,    3.8746,],
       [8.3409,    8.3315,    8.3332,    8.3975,    8.3437,],
       [18.0063,    17.8796,    17.8991,    17.9098,    17.8930,],
       [38.7415,    38.6061,    38.2674,    38.2395,    38.3673,],
       [81.6699,    81.7760,    81.8394,    82.3166,    81.7240,],
       [np.nan, np.nan, np.nan, np.nan, np.nan],
       [np.nan, np.nan, np.nan, np.nan, np.nan],
       [np.nan, np.nan, np.nan, np.nan, np.nan],
       [np.nan, np.nan, np.nan, np.nan, np.nan]]

m_thS = [[942042,    1633174,    1590062,    1620253,    1620253,], 
       [1417301,    1389417,    1410468,    1395095,    1402740,],
       [1204352,    1255671,    1249161,    1087915,    1083885,],
       [1031478,    1120657,    1128375,    1033039,    982843,],
       [1011358,    914235,    1009986,    908305,    1013297,],
       [864454,    908280,    912351,    914056,    911083,],
       [829402,    816790,    827266,    827694,    827360,],
       [753820,    755315,    753994,    752379,    754493,],
       [690163,    690749,    689370,    691031,    689891,],
       [634195,    632741,    634466,    633763,    634641,],
       [584105,    584132,    585002,    584118,    585574,],
       [541452,    541493,    540213,    541773,    541250,],
       [502860,    503430,    503325,    499473,    502688,],
       [465872,    469173,    468660,    468381,    468820,],
       [433055,    434575,    438420,    438740,    437279,],
       [410854,    410321,    410004,    407626,    410582,],
       [np.nan, np.nan, np.nan, np.nan, np.nan],
       [np.nan, np.nan, np.nan, np.nan, np.nan],
       [np.nan, np.nan, np.nan, np.nan, np.nan],
       [np.nan, np.nan, np.nan, np.nan, np.nan]]

m_tP = [[0.0002,    0.0002,    0.0002,    0.0002,    0.0002,], 
       [0.0002,    0.0002,    0.0002,    0.0003,    0.0002,],
       [0.0003,    0.0003,    0.0003,    0.0004,    0.0003,],
       [0.0003,    0.0003,    0.0003,    0.0004,    0.0003,],
       [0.0004,    0.0005,    0.0004,    0.0005,    0.0004,],
       [0.0006,    0.0006,    0.0006,    0.0005,    0.0005,],
       [0.0007,    0.0007,    0.0007,    0.0007,    0.0007,],
       [0.0009,    0.0009,    0.0009,    0.0012,    0.0010,],
       [0.0012,    0.0013,    0.0013,    0.0013,    0.0012,],
       [0.0021,    0.0020,    0.0020,    0.0020,    0.0020,],
       [0.0032,    0.0033,    0.0033,    0.0033,    0.0032,],
       [0.0057,    0.0056,    0.0055,    0.0056,    0.0055,],
       [0.0108,    0.0106,    0.0106,    0.0107,    0.0106,],
       [0.0212,    0.0212,    0.0213,    0.0212,    0.0211,],
       [0.0431,    0.0430,    0.0437,    0.0430,    0.0434,],
       [0.0874,    0.0843,    0.0841,    0.0822,    0.0812,],
       [0.1790,    0.1652,    0.1670,    0.1651,    0.1653,],
       [0.3757,    0.3760,    0.3763,    0.3778,    0.3753,],
       [0.7452,    0.7334,    0.7147,    0.7224,    0.7333,],
       [1.4568,    1.4619,    1.4658,    1.4606,    1.4613,]]

m_thP = [[5657459,     5657459,    6320988,    6095238,    6522293,], 
       [9752381,    10240000,    10778947,    7876923,    10189055,],
       [14576512,    15753846,    13298701,    11377778,    12118343,],
       [24023460,    27582492,    29574007,    22629834,    25680251,],
       [40960000,    31568401,    39290168,    31937622,    41583756,],
       [51200000,    53455139,    58099291,    64887129,    61943289,],
       [100054962,    99296970,    96946746,    96093842,    98550376,],
       [145797553,    139884739,    142935660,    112411664,    134709147,],
       [212262348,    201959938,    204640125,    207885805,    212434360,],
       [255003891,    256878001,    256878001,    256250244,    257382425,],
       [327168799,    319395675,    319298417,    321846532,    323335183,],
       [369281916,    375968447,    382761818,    377525113,    381508459,],
       [389805204,    395390649,    394127420,    393314329,    396399584,],
       [395502499,    396006609,    393775900,    394999670,    396999905,],
       [389127125,    390213188,    383909201,    390503829,    386491649,],
       [383935558,    398248555,    398920880,    408209735,    413104734,],
       [374834469,    406119823,    401738826,    406535599,    406065761,],
       [357228063,    356914581,    356641445,    355243458,    357620216,],
       [360203877,    366037534,    375574979,    371583765,    366052010,],
       [368520704,    367231084,    366276023,    367566734,    367392169,]]

# %%
print(n)
# Out:
# [    1024     2048     4096     8192    16384    32768    65536   131072
#    262144   524288  1048576  2097152  4194304  8388608 16777216 33554432]

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(n, np.mean(b_thS, axis=-1), '-s', c='b')
plt.plot(n, np.mean(b_thP, axis=-1), '-o', c='r')
plt.xscale('log')
plt.yscale('log')
plt.legend(['CPU', 'CUDA'])
plt.xlabel('Elements')
plt.ylabel('Throughput (el/s)')
plt.grid(which='both', axis='y')
plt.grid(which='major', axis='x')
plt.ylim(10**5, 10**9)
plt.title('Bitonic sort')

plt.subplot(1,2,2)
plt.plot(n, np.mean(m_thS, axis=-1), '-s', c='b')
plt.plot(n, np.mean(m_thP, axis=-1), '-o', c='r')
plt.xscale('log')
plt.yscale('log')
plt.legend(['CPU', 'CUDA'])
plt.xlabel('Elements')
plt.ylabel('Throughput (el/s)')
plt.grid(which='both', axis='y')
plt.grid(which='major', axis='x')
plt.ylim(10**5, 10**9)
plt.title('Merge sort')
plt.show()

# %%
plt.figure(figsize=(20,5))
fig, (ax1, ax3) = plt.subplots(1, 2)
fig.set_figwidth(10)
ax2 = ax1.twinx()
ax4 = ax3.twinx()

ax1.plot(n, np.mean(b_tS, axis=-1), '-s', c='b')
ax1.plot(n, np.mean(b_tP, axis=-1), '-o', c='r')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_ylabel('Time (s)')
ax1.legend(['CPU', 'CUDA'], loc='lower right')
ax1.grid(which='both', axis='y', alpha=0.5)
ax1.grid(which='major', axis='x', alpha=0.5)

ax2.plot(n, np.mean(b_tS, axis=-1) / np.mean(b_tP, axis=-1), '-.', c='black')
ax2.legend(['Speedup'], loc='upper left')
ax2.set_yscale('log')
ax2.grid(which='major', c='black', linestyle='--', alpha=0.7)

ax1.set_title('Bitonic sort')
ax1.set_xlabel('Elements')
ax1.set_ylim(10**(-4), 200)
ax1.set_yticks([10**i for i in range(-4, 3)], [10**i for i in range(-4, 3)])
ax2.set_ylim(1, 2000)
ax2.set_yticklabels([])

ax3.plot(n, np.mean(m_tS, axis=-1), '-s', c='b')
ax3.plot(n, np.mean(m_tP, axis=-1), '-o', c='r')
ax3.set_xscale('log')
ax3.set_yscale('log')
ax3.legend(['CPU', 'CUDA'], loc='lower right')
ax3.grid(which='both', axis='y', alpha=0.5)
ax3.grid(which='major', axis='x', alpha=0.5)

ax4.plot(n, np.mean(m_tS, axis=-1) / np.mean(m_tP, axis=-1), '-.', c='black')
ax4.set_ylabel('CUDA vs. CPU Speedup')
ax4.legend(['Speedup'], loc='upper left')
ax4.set_yscale('log')

ax3.set_yticklabels([])
ax3.set_title('Merge sort')
ax3.set_xlabel('Elements')
ax3.set_ylim(10**(-4), 200)
ax4.set_ylim(1, 2000)
ax4.set_yticks([10**i for i in range(4)], [10**i for i in range(4)])
ax4.grid(which='major', c='black', linestyle='--', alpha=0.7)
plt.show()
